# %% [markdown]
# <a href="https://colab.research.google.com/gist/brunohdmacedo/9e13f3a75af20a9547a58c7158578da8/aquisi-o-de-dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
spogpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')

# %%
# !pip install lightkurve
# !pip install sktime

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
book_local = 'shallue_local_curves_'
book_global = 'shallue_global_curves_'
path_input = "/content/drive/MyDrive/Iniciação Científica/IC_Exoplanetas_22-23/Dataset/Dados IC/lighkurve_KOI_dataset.csv"
path_local = '/content/drive/MyDrive/Iniciação Científica/IC_Exoplanetas_22-23/Dataset/Dados IC/Resultados Teste/Resultados teste/' + book_local + '.xlsx'
path_global = '/content/drive/MyDrive/Iniciação Científica/IC_Exoplanetas_22-23/Dataset/Dados IC/Resultados Teste/Resultados teste/' + book_global + '.xlsx'

import pandas as pd
import numpy as np
import time
from lightkurve import search_lightcurve 

lc = pd.read_csv(path_input, sep = ",") 
lc = lc[['kepid','koi_disposition','koi_period','koi_time0bk','koi_duration','koi_quarters']]

lc.shape
print('total inicial de curvas: %d\n'%(lc.shape[0]))

lc = lc.dropna()
lc = lc[lc.koi_disposition != 'CANDIDATE']
lc = lc.reset_index(drop=True)
print('falsos positivos: %d, confirmados: %d\n\ntotal atualizado: %d\n'%((lc.koi_disposition == 'FALSE POSITIVE').sum(),(lc.koi_disposition == 'CONFIRMED').sum(),lc.shape[0]))

perc_class = ((lc.koi_disposition == 'FALSE POSITIVE').sum()*100)/lc.shape[0]
print('falsos positivos: %.2f %% confirmados: %.2f %% \n'%(perc_class,100-perc_class))

import sys
import warnings
warnings.simplefilter("ignore")

curvas_locais = []
labels_locais = []
curvas_globais = []
labels_globais = []
start_time = time.time()
for index, row in lc[5000:6000].iterrows():
  period, t0, duration_hours = row[2], row[3], row[4]

  try:

    lcs = search_lightcurve(str(row[0]), author='Kepler', cadence='long').download_all()

    if (lcs != None):

      lc_raw = lcs.stitch()
      lc_raw.flux.shape

      lc_clean = lc_raw.remove_outliers(sigma=3)

      temp_fold = lc_clean.fold(period, epoch_time=t0)
      fractional_duration = (duration_hours / 24.0) / period
      phase_mask = np.abs(temp_fold.phase.value) < (fractional_duration * 1.5)
      transit_mask = np.in1d(lc_clean.time.value, temp_fold.time_original.value[phase_mask])

      lc_flat, trend_lc = lc_clean.flatten(return_trend=True, mask=transit_mask)

      lc_fold = lc_flat.fold(period, epoch_time=t0)

      #global preprocessing-----------------------------------------------------
      lc_global = lc_fold.bin(bins=2001).normalize() - 1
      lc_global = (lc_global / np.abs(np.nanmin(lc_global.flux)) ) * 2.0 + 1
      lc_global.flux.shape
      #global preprocessing-----------------------------------------------------
    
      phase_mask = (lc_fold.phase > -4*fractional_duration) & (lc_fold.phase < 4.0*fractional_duration)
      lc_zoom = lc_fold[phase_mask]

      #local preprocessing------------------------------------------------------
      lc_local = lc_zoom.bin(bins=201).normalize() - 1
      lc_local = (lc_local / np.abs(np.nanmin(lc_local.flux)) ) * 2.0 + 1
      lc_local.flux.shape
      #local--------------------------------------------------------------------

      labels_locais.append(row[1])
      curvas_locais.append(lc_local.flux.value)

      labels_globais.append(row[1])
      curvas_globais.append(lc_global.flux.value)

      print(index, 'OK')

    else:
      print(index, 'not downloaded')  
    
  except Exception as e:
    print(index, e)

t = time.time() - start_time   

print('Tempo para importar curvas de luz: %f seconds\n' %t)

dataset_global = pd.DataFrame(curvas_globais)
dataset_local = pd.DataFrame(curvas_locais)

for i in range(1,len(curvas_globais)):
    if len(curvas_globais[i]) != len(curvas_globais[i-1]):
        print("A curva %d possui tamanho diferente das demais curvas. Tamanho: %d"%(i,len(curvas_globais[i])))
print("Caso nenhuma das curvas apresente tamanho diferente, todas as curvas GLOBAIS possuem o total de %d pontos cada.\n"%len(curvas_globais[0]))

for i in range(1,len(curvas_locais)):
    if len(curvas_locais[i]) != len(curvas_locais[i-1]):
        print("A curva %d possui tamanho diferente das demais curvas. Tamanho: %d"%(i,len(curvas_locais[i])))
print("Caso nenhuma das curvas apresente tamanho diferente, todas as curvas LOCAIS possuem o total de %d pontos cada.\n"%len(curvas_locais[0]))

print("Quantidade de NaN na base GLOBAL: %s"%dataset_global.isna().sum(axis=1).sum())
print("Quantidade de NaN na base LOCAL: %s\n"%dataset_local.isna().sum(axis=1).sum())

perc_nan_glob = (dataset_global.isna().sum(axis=1).sum()*100)/dataset_global.count(axis=1).sum()
print("Porcentagem de valores do dataset GLOBAL substituídos na interpolação: %.2f %%"%perc_nan_glob)
perc_nan_loc = (dataset_local.isna().sum(axis=1).sum()*100)/dataset_local.count(axis=1).sum()
print("Porcentagem de valores do dataset LOCAL substituídos na interpolação: %.2f %%"%perc_nan_loc)

dataset_global = dataset_global.interpolate(axis=1)
dataset_local = dataset_local.interpolate(axis=1)

print("Quantidade de NaN na base GLOBAL após interpolação: %s --> deve sempre ser zero"%dataset_global.isna().sum(axis=1).sum())
print("Quantidade de NaN na base LOCAL após interpolação: %s --> deve sempre ser zero"%dataset_local.isna().sum(axis=1).sum())

labels_glob = pd.Series(labels_globais)
labels_loc = pd.Series(labels_locais)
dataset_global['label'] = labels_glob
dataset_local['label'] = labels_loc

dataset_global.to_csv(path_global,index=False)  
dataset_local.to_csv(path_local,index=False)
# Out:
# total inicial de curvas: 9564
#
# falsos positivos: 4170, confirmados: 2349
#
# total atualizado: 6519
#
# falsos positivos: 63.97 % confirmados: 36.03 %
#
# 5000 'TimeDelta' object has no attribute 'mjd'
# 5001 'TimeDelta' object has no attribute 'mjd'
# 5002 'TimeDelta' object has no attribute 'mjd'
# 5003 'TimeDelta' object has no attribute 'mjd'
# 5004 'TimeDelta' object has no attribute 'mjd'
# 5005 'TimeDelta' object has no attribute 'mjd'
# 5006 'TimeDelta' object has no attribute 'mjd'
# 5007 'TimeDelta' object has no attribute 'mjd'
# 5008 'TimeDelta' object has no attribute 'mjd'
# 5009 'TimeDelta' object has no attribute 'mjd'
# 5010 'TimeDelta' object has no attribute 'mjd'
# 5011 'TimeDelta' object has no attribute 'mjd'
# 5012 'TimeDelta' object has no attribute 'mjd'
# 5013 'TimeDelta' object has no attribute 'mjd'
# 5014 'TimeDelta' object has no attribute 'mjd'
# 5015 'TimeDelta' object has no attribute 'mjd'
# 5016 'TimeDelta' object has no attribute 'mjd'
# 5017 'TimeDelta' object has no attribute 'mjd'
# 5018 'TimeDelta' object has no attribute 'mjd'
# 5019 'TimeDelta' object has no attribute 'mjd'
# 5020 'TimeDelta' object has no attribute 'mjd'
# 5021 'TimeDelta' object has no attribute 'mjd'
# 5022 'TimeDelta' object has no attribute 'mjd'
# 5023 'TimeDelta' object has no attribute 'mjd'
# 5024 'TimeDelta' object has no attribute 'mjd'
# 5025 'TimeDelta' object has no attribute 'mjd'
# 5026 'TimeDelta' object has no attribute 'mjd'
# 5027 cannot reshape array of size 0 into shape (0,newaxis)
# 5028 'TimeDelta' object has no attribute 'mjd'
# 5029 cannot reshape array of size 0 into shape (0,newaxis)
# 5030 'TimeDelta' object has no attribute 'mjd'
# 5031 'TimeDelta' object has no attribute 'mjd'
# 5032 cannot reshape array of size 0 into shape (0,newaxis)
# 5033 'TimeDelta' object has no attribute 'mjd'
# 5034 'TimeDelta' object has no attribute 'mjd'
# 5035 'TimeDelta' object has no attribute 'mjd'
# 5036 'TimeDelta' object has no attribute 'mjd'
# 5037 'TimeDelta' object has no attribute 'mjd'
# 5038 'TimeDelta' object has no attribute 'mjd'
# 5039 'TimeDelta' object has no attribute 'mjd'
# 5040 'TimeDelta' object has no attribute 'mjd'
# 5041 'TimeDelta' object has no attribute 'mjd'
# 5042 'TimeDelta' object has no attribute 'mjd'
# 5043 'TimeDelta' object has no attribute 'mjd'
# 5044 'TimeDelta' object has no attribute 'mjd'
# 5045 'TimeDelta' object has no attribute 'mjd'
# 5046 'TimeDelta' object has no attribute 'mjd'
# 5047 'TimeDelta' object has no attribute 'mjd'
# 5048 'TimeDelta' object has no attribute 'mjd'
# 5049 'TimeDelta' object has no attribute 'mjd'
# 5050 'TimeDelta' object has no attribute 'mjd'
# 5051 'TimeDelta' object has no attribute 'mjd'
# 5052 'TimeDelta' object has no attribute 'mjd'
# 5053 'TimeDelta' object has no attribute 'mjd'
# 5054 'TimeDelta' object has no attribute 'mjd'
# 5055 'TimeDelta' object has no attribute 'mjd'
# 5056 'TimeDelta' object has no attribute 'mjd'
# 5057 'TimeDelta' object has no attribute 'mjd'
# 5058 'TimeDelta' object has no attribute 'mjd'
# 5059 'TimeDelta' object has no attribute 'mjd'
# 5060 'TimeDelta' object has no attribute 'mjd'
# 5061 'TimeDelta' object has no attribute 'mjd'
# 5062 'TimeDelta' object has no attribute 'mjd'
# 5063 'TimeDelta' object has no attribute 'mjd'
# 5064 'TimeDelta' object has no attribute 'mjd'
# 5065 'TimeDelta' object has no attribute 'mjd'
# 5066 'TimeDelta' object has no attribute 'mjd'
# 5067 'TimeDelta' object has no attribute 'mjd'
# 5068 'TimeDelta' object has no attribute 'mjd'
# 5069 'TimeDelta' object has no attribute 'mjd'
# 5070 'TimeDelta' object has no attribute 'mjd'
# 5071 'TimeDelta' object has no attribute 'mjd'
# 5072 'TimeDelta' object has no attribute 'mjd'
# 5073 'TimeDelta' object has no attribute 'mjd'
# 5074 'TimeDelta' object has no attribute 'mjd'
# 5075 'TimeDelta' object has no attribute 'mjd'
# 5076 'TimeDelta' object has no attribute 'mjd'
# 5077 'TimeDelta' object has no attribute 'mjd'
# 5078 'TimeDelta' object has no attribute 'mjd'
# 5079 'TimeDelta' object has no attribute 'mjd'
# 5080 'TimeDelta' object has no attribute 'mjd'
# 5081 'TimeDelta' object has no attribute 'mjd'
# 5082 'TimeDelta' object has no attribute 'mjd'
# 5083 'TimeDelta' object has no attribute 'mjd'
# 5084 'TimeDelta' object has no attribute 'mjd'
# 5085 'TimeDelta' object has no attribute 'mjd'
# 5086 'TimeDelta' object has no attribute 'mjd'
# 5087 'TimeDelta' object has no attribute 'mjd'
# 5088 'TimeDelta' object has no attribute 'mjd'
# 5089 'TimeDelta' object has no attribute 'mjd'
# 5090 'TimeDelta' object has no attribute 'mjd'
# 5091 'TimeDelta' object has no attribute 'mjd'
# 5092 'TimeDelta' object has no attribute 'mjd'
# 5093 'TimeDelta' object has no attribute 'mjd'
# 5094 'TimeDelta' object has no attribute 'mjd'
# 5095 'TimeDelta' object has no attribute 'mjd'
# 5096 'TimeDelta' object has no attribute 'mjd'
# 5097 'TimeDelta' object has no attribute 'mjd'
# 5098 'TimeDelta' object has no attribute 'mjd'
# 5099 'TimeDelta' object has no attribute 'mjd'
# 5100 'TimeDelta' object has no attribute 'mjd'
# 5101 'TimeDelta' object has no attribute 'mjd'
# 5102 'TimeDelta' object has no attribute 'mjd'
# 5103 'TimeDelta' object has no attribute 'mjd'
# 5104 'TimeDelta' object has no attribute 'mjd'
# 5105 'TimeDelta' object has no attribute 'mjd'
# 5106 'TimeDelta' object has no attribute 'mjd'
# 5107 'TimeDelta' object has no attribute 'mjd'
# 5108 'TimeDelta' object has no attribute 'mjd'
# 5109 'TimeDelta' object has no attribute 'mjd'
# 5110 'TimeDelta' object has no attribute 'mjd'
# 5111 'TimeDelta' object has no attribute 'mjd'
# 5112 'TimeDelta' object has no attribute 'mjd'
# 5113 'TimeDelta' object has no attribute 'mjd'
# 5114 'TimeDelta' object has no attribute 'mjd'
# 5115 'TimeDelta' object has no attribute 'mjd'
# 5116 'TimeDelta' object has no attribute 'mjd'
# 5117 'TimeDelta' object has no attribute 'mjd'
# 5118 'TimeDelta' object has no attribute 'mjd'
# 5119 'TimeDelta' object has no attribute 'mjd'
# 5120 'TimeDelta' object has no attribute 'mjd'
# 5121 'TimeDelta' object has no attribute 'mjd'
# 5122 'TimeDelta' object has no attribute 'mjd'
# 5123 'TimeDelta' object has no attribute 'mjd'
# 5124 'TimeDelta' object has no attribute 'mjd'
# 5125 'TimeDelta' object has no attribute 'mjd'
# 5126 'TimeDelta' object has no attribute 'mjd'
# 5127 'TimeDelta' object has no attribute 'mjd'
# 5128 'TimeDelta' object has no attribute 'mjd'
# 5129 'TimeDelta' object has no attribute 'mjd'
# 5130 'TimeDelta' object has no attribute 'mjd'
# 5131 'TimeDelta' object has no attribute 'mjd'
# 5132 'TimeDelta' object has no attribute 'mjd'
# 5133 'TimeDelta' object has no attribute 'mjd'
# 5134 'TimeDelta' object has no attribute 'mjd'
# 5135 'TimeDelta' object has no attribute 'mjd'
# 5136 'TimeDelta' object has no attribute 'mjd'
# 5137 'TimeDelta' object has no attribute 'mjd'
# 5138 'TimeDelta' object has no attribute 'mjd'
# 5139 'TimeDelta' object has no attribute 'mjd'
# 5140 'TimeDelta' object has no attribute 'mjd'
# 5141 cannot reshape array of size 0 into shape (0,newaxis)
# 5142 'TimeDelta' object has no attribute 'mjd'
# 5143 'TimeDelta' object has no attribute 'mjd'
# 5144 'TimeDelta' object has no attribute 'mjd'
# 5145 'TimeDelta' object has no attribute 'mjd'
# 5146 'TimeDelta' object has no attribute 'mjd'
# 5147 'TimeDelta' object has no attribute 'mjd'
# 5148 'TimeDelta' object has no attribute 'mjd'
# 5149 'TimeDelta' object has no attribute 'mjd'
# 5150 'TimeDelta' object has no attribute 'mjd'
# 5151 'TimeDelta' object has no attribute 'mjd'
# 5152 'TimeDelta' object has no attribute 'mjd'
# 5153 'TimeDelta' object has no attribute 'mjd'
# 5154 'TimeDelta' object has no attribute 'mjd'
# 5155 'TimeDelta' object has no attribute 'mjd'
# 5156 'TimeDelta' object has no attribute 'mjd'
# 5157 'TimeDelta' object has no attribute 'mjd'
# 5158 'TimeDelta' object has no attribute 'mjd'
# 5159 'TimeDelta' object has no attribute 'mjd'
# 5160 'TimeDelta' object has no attribute 'mjd'
# 5161 'TimeDelta' object has no attribute 'mjd'
# 5162 'TimeDelta' object has no attribute 'mjd'
# 5163 'TimeDelta' object has no attribute 'mjd'
# 5164 'TimeDelta' object has no attribute 'mjd'
# 5165 'TimeDelta' object has no attribute 'mjd'
# 5166 'TimeDelta' object has no attribute 'mjd'
# 5167 'TimeDelta' object has no attribute 'mjd'
# 5168 'TimeDelta' object has no attribute 'mjd'
# 5169 'TimeDelta' object has no attribute 'mjd'
# 5170 'TimeDelta' object has no attribute 'mjd'
# 5171 'TimeDelta' object has no attribute 'mjd'
# 5172 'TimeDelta' object has no attribute 'mjd'
# 5173 'TimeDelta' object has no attribute 'mjd'
# 5174 'TimeDelta' object has no attribute 'mjd'
# 5175 'TimeDelta' object has no attribute 'mjd'
# 5176 'TimeDelta' object has no attribute 'mjd'
# 5177 'TimeDelta' object has no attribute 'mjd'
# 5178 'TimeDelta' object has no attribute 'mjd'
# 5179 'TimeDelta' object has no attribute 'mjd'
# 5180 'TimeDelta' object has no attribute 'mjd'
# 5181 'TimeDelta' object has no attribute 'mjd'
# 5182 'TimeDelta' object has no attribute 'mjd'
# 5183 'TimeDelta' object has no attribute 'mjd'
# 5184 'TimeDelta' object has no attribute 'mjd'
# 5185 'TimeDelta' object has no attribute 'mjd'
# 5186 'TimeDelta' object has no attribute 'mjd'
# 5187 cannot reshape array of size 0 into shape (0,newaxis)
# 5188 'TimeDelta' object has no attribute 'mjd'
# 5189 'TimeDelta' object has no attribute 'mjd'
# 5190 'TimeDelta' object has no attribute 'mjd'
# 5191 cannot reshape array of size 0 into shape (0,newaxis)
# 5192 'TimeDelta' object has no attribute 'mjd'
# 5193 'TimeDelta' object has no attribute 'mjd'
# 5194 'TimeDelta' object has no attribute 'mjd'
# 5195 'TimeDelta' object has no attribute 'mjd'
# 5196 'TimeDelta' object has no attribute 'mjd'
# 5197 'TimeDelta' object has no attribute 'mjd'
# 5198 'TimeDelta' object has no attribute 'mjd'
# 5199 'TimeDelta' object has no attribute 'mjd'
# 5200 'TimeDelta' object has no attribute 'mjd'
# 5201 'TimeDelta' object has no attribute 'mjd'
# 5202 'TimeDelta' object has no attribute 'mjd'
# 5203 'TimeDelta' object has no attribute 'mjd'
# 5204 'TimeDelta' object has no attribute 'mjd'
# 5205 'TimeDelta' object has no attribute 'mjd'
# 5206 'TimeDelta' object has no attribute 'mjd'
# 5207 'TimeDelta' object has no attribute 'mjd'
# 5208 'TimeDelta' object has no attribute 'mjd'
# 5209 'TimeDelta' object has no attribute 'mjd'
# 5210 'TimeDelta' object has no attribute 'mjd'
